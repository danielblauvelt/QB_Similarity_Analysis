# %% [markdown]
# HOW TO RUN NOTEBOOK: This notebook can be run in order. The final cell is used for getting the coherence score for different numbers of components. If you choose to run this cell, then you can go back and rerun the code starting from the cell containing the code:
# svd = TruncatedSVD(n_components=20, random_state=42)  # Number of topics
# X_lsa = svd.fit_transform(X)
# This will give you a different set of player comparisons and topics

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import numpy as np

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
df = pd.read_csv('all_draft_classes.csv')

overviews = df['Overview']

# %%
import re

df['Strengths'] = \
df['Strengths'].map(lambda x: re.sub('[,\.!?]', '', x))

df['Weaknesses'] = \
df['Weaknesses'].map(lambda x: re.sub('[,\.!?]', '', x))

df['Overview'] = \
df['Overview'].map(lambda x: re.sub('[,\.!?]', '', x))

df['Strengths'] = 'STRENGTHS: ' + df['Strengths'].astype(str)
df['Weaknesses'] = 'WEAKNESSES: ' + df['Weaknesses'].astype(str)
df.head()
# Out:
#    Year             Name                                           Overview  \
# 0  2025         Cam Ward  Gunslinger with good size a big arm and the mo...
# 1  2025  Shedeur Sanders  Any perceptions that Sanders is a product of H...
# 2  2025      Jaxson Dart  Three-year SEC starter who saw improvement in ...
# 3  2025     Jalen Milroe  Milroe is an explosive athlete who is very cap...
# 4  2025      Will Howard  Howard brings outstanding size and toughness t...
#
#                                            Strengths  \
# 0  STRENGTHS: Recognizes pre-snap pressure and ca...
# 1  STRENGTHS: Plays with confidence and composure...
# 2  STRENGTHS: Gets across the full field of progr...
# 3  STRENGTHS: Unflinching when he delivers throws...
# 4  STRENGTHS: Outstanding size and toughness insi...
#
#                                           Weaknesses Label
# 0  WEAKNESSES: Too willing to work out of structu...   NaN
# 1  WEAKNESSES: Spacing and clearly defined route ...   NaN
# 2  WEAKNESSES: Deep zone coverages slowed his mom...   NaN
# 3  WEAKNESSES: Threw five touchdowns and 10 inter...   NaN
# 4  WEAKNESSES: Very gradual in his setup and rele...   NaN

# %%
stop_words = stopwords.words('english')
lemmatizer = WordNetLemmatizer()
df['composite'] = df['Overview'] + df['Strengths'] + df['Weaknesses']
# Tokenize the sentence
overviews = []
for doc in df['composite']:
    filtered_sentence = [w for w in doc.split() if not w.lower() in stop_words]
    filtered_sentence = [lemmatizer.lemmatize(word) for word in filtered_sentence]
    overviews.append(" ".join(filtered_sentence).lower())

# %%
#transform documents into tf-idf matrix
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(overviews)

# %%
#run SVD
svd = TruncatedSVD(n_components=16, random_state=42) 
X_lsa = svd.fit_transform(X)

# %%
print("Original TF-IDF matrix shape:", X.shape)
print("LSA reduced matrix shape:", X_lsa.shape)
print("LSA components:\n", svd.components_)
# Out:
# Original TF-IDF matrix shape: (179, 4444)
# LSA reduced matrix shape: (179, 16)
# LSA components:
#  [[ 0.00053463  0.00053463  0.02521744 ...  0.04968638  0.00197938
#    0.00532543]
#  [-0.00171739 -0.00171739 -0.01795803 ...  0.07010186 -0.00492206
#    0.01011557]
#  [ 0.00373974  0.00373974  0.07827389 ... -0.01910766  0.01542337
#   -0.00491781]
#  ...
#  [-0.00031578 -0.00031578  0.01043718 ... -0.02311465  0.00871292
#   -0.00720029]
#  [-0.00041496 -0.00041496  0.01531823 ... -0.01640533 -0.00337343
#    0.00393199]
#  [ 0.00059597  0.00059597 -0.01302152 ...  0.02975666 -0.00250666
#    0.00908784]]

# %%
#Examine what words are in each topic
terms = vectorizer.get_feature_names_out()  # Get the terms (words) from TF-IDF vectorizer
topic_words = []
for i, component in enumerate(svd.components_):
    top_terms_idx = component.argsort()[-20:][::-1]  
    top_terms = [terms[idx] for idx in top_terms_idx]  # Get the actual terms
    topic_words.append(top_terms)  # Store the top terms for each topic
    print(f"Component {i+1}: {', '.join(top_terms)}")
# Out:
# Component 1: throw, pocket, ball, play, arm, accuracy, field, make, time, good, deep, nfl, game, quarterback, he, pressure, average, ability, get, talent
# Component 2: he, throw, talent, placement, average, platform, safety, play, anticipation, timing, 2020, zone, off, tape, poise, reader, below, pocket, eye, willing
# Component 3: yard, target, percent, span, hand, inch, bowl, season, touchdown, middle, run, 10, attempt, trying, body, all, school, sideline, last, interception
# Component 4: football, could, smart, percentage, game, duress, action, intangible, heavily, require, highly, respected, tends, dink, dunk, completion, outstanding, works, wave, to
# Component 5: team, play, wilson, luck, 2020, he, athlete, passer, rg3, first, bowl, well, span, inch, game, state, intangible, one, athletic, also
# Component 6: luck, play, rg3, make, able, percent, ability, athletic, likely, 2014, nfl, year, foles, allen, quarterback, harnish, learn, ease, talented, simply
# Component 7: improve, open, snap, toughness, accuracy, footwork, pre, defender, flashes, big, intermediate, clean, stanzi, quickness, built, beat, making, leadership, quality, leg
# Component 8: enough, many, intangible, kaepernick, last, could, make, team, timing, adequate, delivery, style, delivers, beyond, consistent, pro, toughness, dip, drive, outside
# Component 9: average, wilson, lindley, one, 2018, day, top, early, foles, good, ball, percentage, below, luck, adequate, rarely, strength, field, completion, off
# Component 10: yard, order, tebow, throwing, runner, needs, mechanic, athletic, recognition, interception, attempt, need, quickness, dual, slow, toughness, leg, scheme, threat, quarterback
# Component 11: injury, decision, making, 2022, great, poor, locker, career, footwork, often, point, much, lock, line, 2023, eye, levis, ability, interception, excellent
# Component 12: foot, locker, production, luck, window, work, anticipation, zone, athleticism, athletic, one, start, tight, coverage, man, works, ability, snap, senior, downfield
# Component 13: offense, average, well, scheme, career, dalton, style, pocket, ability, tall, poor, mobile, injury, delaware, however, offensive, confidence, passer, leader, locker
# Component 14: coleman, 2014, game, number, year, starting, tannehill, enough, time, luck, moving, take, receiver, set, season, work, good, attempt, quickness, sense
# Component 15: wilson, throw, robinson, buy, defender, time, one, 2011, coach, zone, platform, though, stanzi, must, body, lot, impressive, pocket, great, thompson
# Component 16: decision, offense, better, team, interception, time, built, job, harnish, size, experience, run, out, spread, become, like, intermediate, deep, lindley, downfield

# %%
#Generate player comparisons
from sklearn.metrics.pairwise import cosine_similarity
similar_players = []
for i, v1 in enumerate(X_lsa):
    most_similar = 0
    player = None
    for j, v2 in enumerate(X_lsa):
        if i != j:
            similarity = cosine_similarity(v1.reshape(1, -1), v2.reshape(1, -1))
            if similarity[0][0] > most_similar:
                most_similar = similarity[0][0]
                player = df.iloc[j]['Name']
    similar_players.append(player)
    print(df.iloc[i]['Name'], 'is most similar to', player, 'with similarity:', most_similar)
# Out:
# Cam Ward is most similar to Drake Maye with similarity: 0.8354728769682168
# Shedeur Sanders is most similar to Desmond Ridder with similarity: 0.8487506574094439
# Jaxson Dart is most similar to Ryan Finley with similarity: 0.8333668444408866
# Jalen Milroe is most similar to Matt Barkley with similarity: 0.8033066881552291
# Will Howard is most similar to Riley Leonard with similarity: 0.9370398780903564
# Kyle McCord is most similar to Bailey Zappe with similarity: 0.8571613167590146
# Tyler Shough is most similar to Jordan Travis with similarity: 0.8154626340561049
# Quinn Ewers is most similar to Ryan Finley with similarity: 0.806327247659282
# Dillon Gabriel is most similar to Cam Ward with similarity: 0.7999205418508317
# Riley Leonard is most similar to Will Howard with similarity: 0.9370398780903564
# Caleb Williams is most similar to Drake Maye with similarity: 0.8447698093499749
# Jayden Daniels is most similar to Kyle Trask with similarity: 0.8952585861168113
# Drake Maye is most similar to Caleb Williams with similarity: 0.8447698093499749
# Michael Penix Jr. is most similar to Mike White with similarity: 0.85337518084715
# JJ McCarthy is most similar to Dorian Thompson-Robinson with similarity: 0.8570034004957312
# Bo Nix is most similar to Kyler Murray with similarity: 0.9046023306882393
# Spencer Rattler is most similar to Lamar Jackson with similarity: 0.8679531772240134
# Jordan Travis is most similar to Tyler Shough with similarity: 0.8154626340561049
# Joe Milton is most similar to Luke Falk with similarity: 0.8250556620694949
# Bryce Young is most similar to Tua Tagovailoa with similarity: 0.8512709515082615
# CJ Stroud is most similar to Aidan O'Connell with similarity: 0.8295014205191609
# Anthony Richardson is most similar to Malik Willis with similarity: 0.9175535020561616
# Will Levis is most similar to Kenny Pickett with similarity: 0.8102138330327705
# Hendon Hooker is most similar to Malik Willis with similarity: 0.802877534109451
# Stetson Bennett is most similar to Jake Luton with similarity: 0.8426881576898665
# Aidan O'Connell is most similar to Davis Webb with similarity: 0.9033775332837594
# Clayton Tune is most similar to Quinn Ewers with similarity: 0.7654036833153905
# Dorian Thompson-Robinson is most similar to Sam Howell with similarity: 0.9080447757537409
# Kenny Pickett is most similar to Chris Oladokun with similarity: 0.9020348908162257
# Desmond Ridder is most similar to Jacob Eason with similarity: 0.8533526840665194
# Malik Willis is most similar to Anthony Richardson with similarity: 0.9175535020561616
# Matt Corral is most similar to Trey Lance with similarity: 0.8687163611251298
# Bailey Zappe is most similar to Ryan Finley with similarity: 0.8850310616589477
# Sam Howell is most similar to Dorian Thompson-Robinson with similarity: 0.9080447757537409
# Chris Oladokun is most similar to Kenny Pickett with similarity: 0.9020348908162257
# Skyler Thompson is most similar to Clayton Thorson with similarity: 0.7996725949200154
# Brock Purdy is most similar to Spencer Rattler with similarity: 0.8533126089339959
# Trevor Lawrence is most similar to Patrick Mahomes with similarity: 0.8728622718943132
# Zach Wilson is most similar to Mac Jones with similarity: 0.8223474426292229
# Trey Lance is most similar to Tua Tagovailoa with similarity: 0.877860581472256
# Justin Fields is most similar to Desmond Ridder with similarity: 0.8123122119078785
# Mac Jones is most similar to Zach Wilson with similarity: 0.8223474426292229
# Kyle Trask is most similar to Davis Mills with similarity: 0.8986416025016383
# Kellen Mond is most similar to Ian Book with similarity: 0.8944385330621942
# Davis Mills is most similar to Kyle Trask with similarity: 0.8986416025016383
# Ian Book is most similar to Kellen Mond with similarity: 0.8944385330621942
# Sam Ehlinger is most similar to Nathan Peterman with similarity: 0.7909404733861081
# Joe Burrow is most similar to Easton Stick with similarity: 0.8840421700771147
# Tua Tagovailoa is most similar to Malik Willis with similarity: 0.8932957687293747
# Justin Herbert is most similar to Drew Lock with similarity: 0.9247824061091534
# Jordan Love is most similar to Jacob Fromm with similarity: 0.853983303371935
# Jalen Hurts is most similar to Malik Willis with similarity: 0.8195107044366319
# Jacob Eason is most similar to Desmond Ridder with similarity: 0.8533526840665194
# James Morgan is most similar to Kevin Hogan with similarity: 0.8744815397986704
# Jacob Fromm is most similar to Justin Herbert with similarity: 0.8555724335924355
# Jake Luton is most similar to Logan Woodside with similarity: 0.917600435171831
# Cole Mcdonald is most similar to Brad Kaaya with similarity: 0.8340852017007983
# Ben Dinucci is most similar to Jacob Fromm with similarity: 0.7880909938903856
# Tommy Stevens is most similar to Dillon Gabriel with similarity: 0.7529149501727076
# Nate Stanley is most similar to Daniel Jones with similarity: 0.8991590931286966
# Kyler Murray is most similar to Bo Nix with similarity: 0.9046023306882393
# Daniel Jones is most similar to Josh Allen with similarity: 0.9029751832352718
# Dwayne Haskins is most similar to Drew Lock with similarity: 0.8493463010459581
# Drew Lock is most similar to Justin Herbert with similarity: 0.9247824061091534
# Will Grier is most similar to James Morgan with similarity: 0.8698004500469669
# Ryan Finley is most similar to Bailey Zappe with similarity: 0.8850310616589477
# Jarrett Stidham is most similar to Nathan Enderle with similarity: 0.816258254084146
# Easton Stick is most similar to Joe Burrow with similarity: 0.8840421700771147
# Clayton Thorson is most similar to Mason Rudolph with similarity: 0.8709403607333212
# Gardner Minshew is most similar to Brad Kaaya with similarity: 0.8666857417342352
# Trace McSorley is most similar to Nate Stanley with similarity: 0.8424646590158742
# Baker Mayfield is most similar to Brad Kaaya with similarity: 0.8047124644699004
# Sam Darnold is most similar to Nate Sudfeld with similarity: 0.871873051335835
# Josh Allen is most similar to Daniel Jones with similarity: 0.9029751832352718
# Josh Rosen is most similar to Brandon Doughty with similarity: 0.907360333267619
# Lamar Jackson is most similar to Patrick Mahomes with similarity: 0.8838069706118272
# Mason Rudolph is most similar to DeShone Kizer with similarity: 0.8847612261095568
# Mike White is most similar to Michael Penix Jr. with similarity: 0.85337518084715
# Luke Falk is most similar to Nate Stanley with similarity: 0.8856948428690451
# Tanner Lee is most similar to Mason Rudolph with similarity: 0.775755655486452
# Danny Etling is most similar to Mitchell Trubisky with similarity: 0.8738460876076892
# Logan Woodside is most similar to Jake Luton with similarity: 0.917600435171831
# Mitchell Trubisky is most similar to Nathan Peterman with similarity: 0.8976559335694964
# Patrick Mahomes is most similar to Lamar Jackson with similarity: 0.8838069706118272
# Deshaun Watson is most similar to Mason Rudolph with similarity: 0.8667162076702084
# DeShone Kizer is most similar to Mason Rudolph with similarity: 0.8847612261095568
# Davis Webb is most similar to Aidan O'Connell with similarity: 0.9033775332837594
# CJ Beathard is most similar to Davis Webb with similarity: 0.8654115413607204
# Josh Dobbs is most similar to Nate Sudfeld with similarity: 0.8633494802772443
# Nathan Peterman is most similar to Mitchell Trubisky with similarity: 0.8976559335694964
# Brad Kaaya is most similar to Gardner Minshew with similarity: 0.8666857417342352
# Chad Kelly is most similar to Brandon Allen with similarity: 0.8692084829369682
# Jared Goff is most similar to Carson Wentz with similarity: 0.8629224752599078
# Carson Wentz is most similar to Jeff Driskel with similarity: 0.8739525766947009
# Paxton Lynch is most similar to Lamar Jackson with similarity: 0.8591880089196787
# Jacoby Brissett is most similar to Connor Cook with similarity: 0.8310641165510775
# Cody Kessler is most similar to Aidan O'Connell with similarity: 0.8318310068498389
# Connor Cook is most similar to Brandon Doughty with similarity: 0.9060005315978888
# Dak Prescott is most similar to Marcus Mariota with similarity: 0.8466604959354068
# Cardale Jones is most similar to Mitchell Trubisky with similarity: 0.8585186657607671
# Kevin Hogan is most similar to James Morgan with similarity: 0.8744815397986704
# Nate Sudfeld is most similar to Sam Darnold with similarity: 0.871873051335835
# Brandon Allen is most similar to Chad Kelly with similarity: 0.8692084829369682
# Jeff Driskel is most similar to Carson Wentz with similarity: 0.8739525766947009
# Brandon Doughty is most similar to Josh Rosen with similarity: 0.907360333267619
# Jameis Winston is most similar to Marcus Mariota with similarity: 0.9087707269843739
# Marcus Mariota is most similar to Jameis Winston with similarity: 0.9087707269843739
# Garrett Grayson is most similar to Mason Rudolph with similarity: 0.8611186697367974
# Sean Mannion is most similar to Aidan O'Connell with similarity: 0.8671854063428548
# Bryce Petty is most similar to Paxton Lynch with similarity: 0.8539594300041715
# Brett Hundley is most similar to Dak Prescott with similarity: 0.7680310422296518
# Blake Bortles is most similar to Aaron Murray with similarity: 0.8850211427506484
# Johnny Manziel is most similar to Zach Mettenberger with similarity: 0.8076909687705326
# Teddy Bridgewater is most similar to Jimmy Garoppolo with similarity: 0.8143018738407116
# Derek Carr is most similar to Tajh Boyd with similarity: 0.7813112233294239
# Jimmy Garoppolo is most similar to AJ McCarron with similarity: 0.9007303352353687
# Logan Thomas is most similar to Tajh Boyd with similarity: 0.7933918842301957
# Tom Savage is most similar to Tajh Boyd with similarity: 0.7725270560916334
# Aaron Murray is most similar to Blake Bortles with similarity: 0.8850211427506484
# AJ McCarron is most similar to Jimmy Garoppolo with similarity: 0.9007303352353687
# Zach Mettenberger is most similar to AJ McCarron with similarity: 0.8628258019441222
# David Fales is most similar to Tajh Boyd with similarity: 0.7377856509075491
# Keith Wenning is most similar to Jimmy Garoppolo with similarity: 0.8462832143073563
# Tajh Boyd is most similar to Logan Thomas with similarity: 0.7933918842301957
# Garrett Gilbert is most similar to Colt McCoy with similarity: 0.7232433156893708
# EJ Manuel is most similar to Matt Barkley with similarity: 0.8178664826843001
# Geno Smith is most similar to Matt Barkley with similarity: 0.8790664103691843
# Mike Glennon is most similar to Josh Freeman with similarity: 0.7671202350620008
# Matt Barkley is most similar to Geno Smith with similarity: 0.8790664103691843
# Ryan Nassib is most similar to Matt Barkley with similarity: 0.8209276677250266
# Tyler Wilson is most similar to Russell Wilson with similarity: 0.8191089112393397
# Landry Jones is most similar to Zach Mettenberger with similarity: 0.8020729478895867
# Brad Sorenson is most similar to Matt Barkley with similarity: 0.8113434136454284
# Zac Dysert is most similar to Geno Smith with similarity: 0.8666833138140291
# Sean Renfree is most similar to Sam Bradford with similarity: 0.7454859648334475
# Andrew Luck is most similar to Robert Griffin III with similarity: 0.9630413140871554
# Robert Griffin III is most similar to Andrew Luck with similarity: 0.9630413140871554
# Ryan Tannehill is most similar to Brock Osweiler with similarity: 0.7125355728485956
# Brandon Weeden is most similar to Aaron Rodgers with similarity: 0.8192831212952872
# Brock Osweiler is most similar to Andrew Luck with similarity: 0.8821076601777711
# Russell Wilson is most similar to Tyler Wilson with similarity: 0.8191089112393397
# Nick Foles is most similar to Ryan Lindley with similarity: 0.9133672683206558
# Kirk Cousins is most similar to Ryan Lindley with similarity: 0.7796687013125163
# Ryan Lindley is most similar to Nick Foles with similarity: 0.9133672683206558
# BJ Coleman is most similar to Nick Foles with similarity: 0.8058266905971003
# Chandler Harnish is most similar to Kirk Cousins with similarity: 0.7165914928970436
# Cam Newton is most similar to Ryan Mallett with similarity: 0.9066086664748366
# Jake Locker is most similar to Tyrod Taylor with similarity: 0.9303470768632249
# Blaine Gabbert is most similar to Andy Dalton with similarity: 0.8660217776072391
# Christian Ponder is most similar to Ricky Stanzi with similarity: 0.9267566434913849
# Andy Dalton is most similar to Blaine Gabbert with similarity: 0.8660217776072391
# Colin Kaepernick is most similar to Greg McElroy with similarity: 0.7479265139298779
# Ryan Mallett is most similar to Cam Newton with similarity: 0.9066086664748366
# Ricky Stanzi is most similar to Christian Ponder with similarity: 0.9267566434913849
# TJ Yates is most similar to Christian Ponder with similarity: 0.8388379699227215
# Nathan Enderle is most similar to Jarrett Stidham with similarity: 0.816258254084146
# Tyrod Taylor is most similar to Jake Locker with similarity: 0.9303470768632249
# Greg McElroy is most similar to Zac Robinson with similarity: 0.9131583424887116
# Sam Bradford is most similar to Brandon Weeden with similarity: 0.7741408152213564
# Tim Tebow is most similar to Dan Lefevour with similarity: 0.8892626903992176
# Jimmy Clausen is most similar to Mike Kafka with similarity: 0.8211089124357134
# Colt McCoy is most similar to John Skelton with similarity: 0.8134658891700405
# Mike Kafka is most similar to Levi Brown with similarity: 0.9344267769827441
# John Skelton is most similar to Aaron Rodgers with similarity: 0.8441228851610142
# Dan Lefevour is most similar to Tim Tebow with similarity: 0.8892626903992176
# Tony Pike is most similar to Mike Kafka with similarity: 0.8338162133667681
# Levi Brown is most similar to Mike Kafka with similarity: 0.9344267769827441
# Sean Canfield is most similar to Greg McElroy with similarity: 0.8191665584342556
# Zac Robinson is most similar to Greg McElroy with similarity: 0.9131583424887116
# Matthew Stafford is most similar to Mark Sanchez with similarity: 0.916044751980887
# Mark Sanchez is most similar to Matthew Stafford with similarity: 0.916044751980887
# Josh Freeman is most similar to Mark Sanchez with similarity: 0.887550837184761
# Pat White is most similar to Josh Freeman with similarity: 0.8797147314560037
# Rhett Bomar is most similar to Matthew Stafford with similarity: 0.9119450396713062
# Matt Ryan is most similar to Drew Brees with similarity: 0.916688748319923
# Joe Flacco is most similar to Zac Dysert with similarity: 0.7842167877571811
# Drew Brees is most similar to Matt Ryan with similarity: 0.916688748319923
# Aaron Rodgers is most similar to John Skelton with similarity: 0.8441228851610142
# Michael Vick is most similar to Drew Brees with similarity: 0.8647442038118193

# %%
#coherence score
from gensim.models import CoherenceModel
import gensim.corpora as corpora

def get_Cv(model, df_columnm):
  topics = model.components_

  n_top_words = 20
  texts = [[word for word in doc.split()] for doc in df_columnm]

  # create the dictionary
  dictionary = corpora.Dictionary(texts)
  # Create a gensim dictionary from the word count matrix

  feature_names = [dictionary[i] for i in range(len(dictionary))]
  # Get the top words for each topic from the components_ attribute
  top_words = []
  for topic in topics:
      top_words.append([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]])

  coherence_model = CoherenceModel(topics=top_words, texts=texts, dictionary=dictionary, coherence='c_v')
  coherence = coherence_model.get_coherence()
  return coherence

coherence = get_Cv(svd, df['composite'])
print(coherence)
# Out:
# 0.7512626614658426

# %%
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora.dictionary import Dictionary
from nltk.corpus import stopwords
import nltk
#u_mass coherence score

texts = [doc.split() for doc in overviews]
dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]
coherence_model = CoherenceModel(
    topics=topic_words,
    corpus=corpus,
    dictionary=dictionary,
    coherence='u_mass'  # Other options: 'u_mass', 'c_uci', 'c_npmi'
)

coherence_score = coherence_model.get_coherence()
print(f"Coherence Score: {coherence_score:.4f}")
# Out:
# Coherence Score: -3.6574

# %%
#NOTE used for determining optimal number of components
optimal_components = 0
for i in range(15, 25):
    svd = TruncatedSVD(n_components=i)  # Number of topics
    X_lsa = svd.fit_transform(X)
    cv = get_Cv(svd, df['composite'])
    print('coherence', cv, 'components', i)
    if cv > coherence:
        coherence = cv
        optimal_components = i
# Out:
# ['2024', '25', '39%', 'Able', 'Alters', 'Arm', 'Bobs', 'Can', 'Capable', 'Completed', 'Displays', 'Drop-down', 'Focus', 'Football', 'Georgia', 'Gets', 'Gunslinger', 'He', 'Inconsistent', 'Like', 'Mobility', 'NFL', 'Needs', 'Pocket', 'Pro', 'QB-hunters', 'Rears', 'Recognizes', 'Release', 'Seam', 'Struggled', 'Sudden', 'Tech’s', 'Too', 'Unjustifiable', 'Ward', 'While', 'With', 'a', 'ability', 'accentuate', 'accuracy', 'against', 'aggressive', 'all', 'and', 'arm', 'around', 'attacking', 'average', 'away', 'back', 'backward', 'ball', 'become', 'before', 'better', 'big', 'blanket', 'bolt', 'breaks', 'bucket', 'but', 'can', 'cannot', 'cause', 'class', 'combo', 'consistent', 'contractSTRENGTHS:', 'coordinator', 'could', 'cover', 'coverage', 'coverages', 'creates', 'cross-field', 'cuts', 'decision-making', 'defender’s', 'delivery', 'develop', 'develops', 'discipline', 'disguised', 'doesn’t', 'down', 'draft', 'dual-threat', 'efficiency', 'elements', 'erratic', 'excited', 'extend', 'eye', 'eyes', 'fairly', 'feast-or-famine', 'feet', 'field', 'figuring', 'finesse', 'first', 'fit', 'for', 'from', 'front', 'full', 'game', 'get', 'given', 'gold', 'good', 'has', 'he', 'help', 'helps', 'hero', 'he’s', 'him', 'himself', 'his', 'holes', 'in', 'inconsistencies', 'inside', 'interceptions', 'into', 'is', 'it', 'just', 'learn', 'legs', 'level', 'levels', 'limit', 'line', 'longer', 'looks', 'loose', 'make', 'mechanics', 'mine', 'mobility', 'more', 'move', 'needed', 'needs', 'not', 'nurturing', 'of', 'off-schedule', 'offensive', 'on', 'operates', 'opportunities', 'others', 'out', 'overlaps', 'passer', 'passes', 'patient', 'pay', 'per', 'physical', 'placement', 'plan', 'play', 'plays', 'pocket', 'points', 'pre-snap', 'pressure', 'prevent', 'pro', 'processing', 'progression', 'protect', 'quarterback', 'quick', 'quickness', 'reaction', 'read', 'reads', 'reckless', 'recognition', 'red', 'regardless', 'regulating', 'release', 'rhythm', 'rich', 'rips', 'rockets', 'route', 'runner', 'scanning', 'scheme', 'scrambles', 'seam', 'second-action', 'security', 'sees', 'shortstop', 'side', 'sidearm', 'size', 'skill', 'spottier', 'starter', 'sticks', 'strike', 'structure', 'take', 'talent', 'than', 'that', 'the', 'this', 'three', 'thrive', 'throw', 'throws', 'throws;', 'tight', 'time', 'times', 'to', 'tools', 'touch', 'trajectory', 'tying', 'uncomfortable', 'unnecessarilyWEAKNESSES:', 'velocity', 'vertical', 'weaves', 'when', 'while', 'whip', 'who', 'will', 'willing', 'windows', 'with', 'work', 'yards', 'zone', 'Allows', 'Any', 'Appears', 'Average', 'Consistently', 'Doesn’t', 'Drops', 'Has', 'Heisman', 'He’s', 'Hits', 'Hunter’s', 'Keeps', 'Much', 'OK', 'Plays', 'Sanders', 'Shows', 'Spacing', 'Steps', 'The', 'Throws', 'Travis', 'Trophy-winner', 'Willing', 'accurate', 'after', 'allows', 'alternate', 'an', 'anticipation', 'appears', 'are', 'as', 'athletes', 'balanced', 'baseline', 'be', 'becoming', 'between', 'beyond', 'bright', 'bringing', 'buy', 'catch', 'clean', 'clearly', 'combinations', 'command', 'complete', 'completions', 'composure', 'compresses', 'confidence', 'confident', 'decent', 'defined', 'depth', 'despite', 'dispelled', 'do', 'downfield', 'drive', 'drops', 'easier', 'edge', 'escapability', 'ever', 'expected', 'faster', 'finds', 'gets', 'greatness', 'half', 'hashes', 'hips', 'hit', 'if', 'ill-advised', 'instead', 'integral', 'intensely', 'lack', 'launch', 'leads', 'limitations', 'locked', 'look', 'lower', 'manager', 'mean', 'mixed', 'mobile', 'moving', 'much', 'necessary', 'no', 'off', 'off-platform', 'offer', 'often', 'on-frame', 'on-platform;', 'on-time', 'once', 'operate', 'operation', 'or', 'pass', 'path', 'perceptions', 'platformWEAKNESSES:', 'point', 'poise', 'possesses', 'product', 'profits', 'proper', 'pros', 'pump', 'punishment', 'puts', 'qualities', 'receivers', 'reset', 'results', 'rip', 'rollout', 'routes', 'rusher’s', 'sack', 'sacks', 'said', 'savvy', 'says', 'seen', 'signs', 'slow-twitch', 'slower', 'slowly', 'so', 'solid', 'spotlight', 'squ ...
# coherence 0.7420223408890014 components 15
# ['2024', '25', '39%', 'Able', 'Alters', 'Arm', 'Bobs', 'Can', 'Capable', 'Completed', 'Displays', 'Drop-down', 'Focus', 'Football', 'Georgia', 'Gets', 'Gunslinger', 'He', 'Inconsistent', 'Like', 'Mobility', 'NFL', 'Needs', 'Pocket', 'Pro', 'QB-hunters', 'Rears', 'Recognizes', 'Release', 'Seam', 'Struggled', 'Sudden', 'Tech’s', 'Too', 'Unjustifiable', 'Ward', 'While', 'With', 'a', 'ability', 'accentuate', 'accuracy', 'against', 'aggressive', 'all', 'and', 'arm', 'around', 'attacking', 'average', 'away', 'back', 'backward', 'ball', 'become', 'before', 'better', 'big', 'blanket', 'bolt', 'breaks', 'bucket', 'but', 'can', 'cannot', 'cause', 'class', 'combo', 'consistent', 'contractSTRENGTHS:', 'coordinator', 'could', 'cover', 'coverage', 'coverages', 'creates', 'cross-field', 'cuts', 'decision-making', 'defender’s', 'delivery', 'develop', 'develops', 'discipline', 'disguised', 'doesn’t', 'down', 'draft', 'dual-threat', 'efficiency', 'elements', 'erratic', 'excited', 'extend', 'eye', 'eyes', 'fairly', 'feast-or-famine', 'feet', 'field', 'figuring', 'finesse', 'first', 'fit', 'for', 'from', 'front', 'full', 'game', 'get', 'given', 'gold', 'good', 'has', 'he', 'help', 'helps', 'hero', 'he’s', 'him', 'himself', 'his', 'holes', 'in', 'inconsistencies', 'inside', 'interceptions', 'into', 'is', 'it', 'just', 'learn', 'legs', 'level', 'levels', 'limit', 'line', 'longer', 'looks', 'loose', 'make', 'mechanics', 'mine', 'mobility', 'more', 'move', 'needed', 'needs', 'not', 'nurturing', 'of', 'off-schedule', 'offensive', 'on', 'operates', 'opportunities', 'others', 'out', 'overlaps', 'passer', 'passes', 'patient', 'pay', 'per', 'physical', 'placement', 'plan', 'play', 'plays', 'pocket', 'points', 'pre-snap', 'pressure', 'prevent', 'pro', 'processing', 'progression', 'protect', 'quarterback', 'quick', 'quickness', 'reaction', 'read', 'reads', 'reckless', 'recognition', 'red', 'regardless', 'regulating', 'release', 'rhythm', 'rich', 'rips', 'rockets', 'route', 'runner', 'scanning', 'scheme', 'scrambles', 'seam', 'second-action', 'security', 'sees', 'shortstop', 'side', 'sidearm', 'size', 'skill', 'spottier', 'starter', 'sticks', 'strike', 'structure', 'take', 'talent', 'than', 'that', 'the', 'this', 'three', 'thrive', 'throw', 'throws', 'throws;', 'tight', 'time', 'times', 'to', 'tools', 'touch', 'trajectory', 'tying', 'uncomfortable', 'unnecessarilyWEAKNESSES:', 'velocity', 'vertical', 'weaves', 'when', 'while', 'whip', 'who', 'will', 'willing', 'windows', 'with', 'work', 'yards', 'zone', 'Allows', 'Any', 'Appears', 'Average', 'Consistently', 'Doesn’t', 'Drops', 'Has', 'Heisman', 'He’s', 'Hits', 'Hunter’s', 'Keeps', 'Much', 'OK', 'Plays', 'Sanders', 'Shows', 'Spacing', 'Steps', 'The', 'Throws', 'Travis', 'Trophy-winner', 'Willing', 'accurate', 'after', 'allows', 'alternate', 'an', 'anticipation', 'appears', 'are', 'as', 'athletes', 'balanced', 'baseline', 'be', 'becoming', 'between', 'beyond', 'bright', 'bringing', 'buy', 'catch', 'clean', 'clearly', 'combinations', 'command', 'complete', 'completions', 'composure', 'compresses', 'confidence', 'confident', 'decent', 'defined', 'depth', 'despite', 'dispelled', 'do', 'downfield', 'drive', 'drops', 'easier', 'edge', 'escapability', 'ever', 'expected', 'faster', 'finds', 'gets', 'greatness', 'half', 'hashes', 'hips', 'hit', 'if', 'ill-advised', 'instead', 'integral', 'intensely', 'lack', 'launch', 'leads', 'limitations', 'locked', 'look', 'lower', 'manager', 'mean', 'mixed', 'mobile', 'moving', 'much', 'necessary', 'no', 'off', 'off-platform', 'offer', 'often', 'on-frame', 'on-platform;', 'on-time', 'once', 'operate', 'operation', 'or', 'pass', 'path', 'perceptions', 'platformWEAKNESSES:', 'point', 'poise', 'possesses', 'product', 'profits', 'proper', 'pros', 'pump', 'punishment', 'puts', 'qualities', 'receivers', 'reset', 'results', 'rip', 'rollout', 'routes', 'rusher’s', 'sack', 'sacks', 'said', 'savvy', 'says', 'seen', 'signs', 'slow-twitch', 'slower', 'slowly', 'so', 'solid', 'spotlight', 'squ ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 6
#       4 svd = TruncatedSVD(n_components=i)  # Number of topics
#       5 X_lsa = svd.fit_transform(X)
# ----> 6 cv = get_Cv(svd, df['composite'])
#       7 print('coherence', cv, 'components', i)
#       8 if cv > coherence:
#
# Cell In[11], line 23, in get_Cv(model, df_columnm)
#      20     top_words.append([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]])
#      22 coherence_model = CoherenceModel(topics=top_words, texts=texts, dictionary=dictionary, coherence='c_v')
# ---> 23 coherence = coherence_model.get_coherence()
#      24 return coherence
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gensim\models\coherencemodel.py:614, in CoherenceModel.get_coherence(self)
#     605 def get_coherence(self):
#     606     """Get coherence value based on pipeline parameters.
#     607
#     608     Returns
#    (...)
#     612
#     613     """
# --> 614     confirmed_measures = self.get_coherence_per_topic()
#     615     return self.aggregate_measures(confirmed_measures)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gensim\models\coherencemodel.py:574, in CoherenceModel.get_coherence_per_topic(self, segmented_topics, with_std, with_support)
#     572     segmented_topics = measure.seg(self.topics)
#     573 if self._accumulator is None:
# --> 574     self.estimate_probabilities(segmented_topics)
#     576 kwargs = dict(with_std=with_std, with_support=with_support)
#     577 if self.coherence in BOOLEAN_DOCUMENT_BASED or self.coherence == 'c_w2v':
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gensim\models\coherencemodel.py:546, in CoherenceModel.estimate_probabilities(self, segmented_topics)
#     543     if self.coherence == 'c_w2v':
#     544         kwargs['model'] = self.keyed_vectors
# --> 546     self._accumulator = self.measure.prob(**kwargs)
#     548 return self._accumulator
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gensim\topic_coherence\probability_estimation.py:156, in p_boolean_sliding_window(texts, segmented_topics, dictionary, window_size, processes)
#     154     accumulator = ParallelWordOccurrenceAccumulator(processes, top_ids, dictionary)
#     155 logger.info("using %s to estimate probabilities from sliding windows", accumulator)
# --> 156 return accumulator.accumulate(texts, window_size)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gensim\topic_coherence\text_analysis.py:437, in ParallelWordOccurrenceAccumulator.accumulate(self, texts, window_size)
#     436 def accumulate(self, texts, window_size):
# --> 437     workers, input_q, output_q = self.start_workers(window_size)
#     438     try:
#     439         self.queue_all_texts(input_q, texts, window_size)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\gensim\topic_coherence\text_analysis.py:471, in ParallelWordOccurrenceAccumulator.start_workers(self, window_size)
#     469     accumulator = PatchedWordOccurrenceAccumulator(self.relevant_ids, self.dictionary)
#     470     worker = AccumulatingWorker(input_q, output_q, accumulator, window_size)
# --> 471     worker.start()
#     472     workers.append(worker)
#     474 return workers, input_q, output_q
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\multiprocessing\process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\multiprocessing\context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\multiprocessing\context.py:327, in SpawnProcess._Popen(process_obj)
#     324 @staticmethod
#     325 def _Popen(process_obj):
#     326     from .popen_spawn_win32 import Popen
# --> 327     return Popen(process_obj)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\multiprocessing\popen_spawn_win32.py:93, in Popen.__init__(self, process_obj)
#      91 try:
#      92     reduction.dump(prep_data, to_child)
# ---> 93     reduction.dump(process_obj, to_child)
#      94 finally:
#      95     set_spawning_popen(None)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\multiprocessing\reduction.py:60, in dump(obj, file, protocol)
#      58 def dump(obj, file, protocol=None):
#      59     '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60     ForkingPickler(file, protocol).dump(obj)
#
# KeyboardInterrupt:
